# %%
import orchest

from pycaret.regression import setup, compare_models, get_config, save_config

# %%
data = orchest.get_inputs()["data"]

# %%
reg1 = setup(data = data, target = 'charges', train_size = 0.5, silent=True)
# Out:
# <style  type="text/css" >
#     #T_77c4caa2_6fad_11ec_84f5_0242ac140012row42_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_77c4caa2_6fad_11ec_84f5_0242ac140012" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_77c4caa2_6fad_11ec_84f5_0242ac140012level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_77c4caa2_6fad_11ec_84f5_0242ac140012row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_77c4caa2_6fad_11ec_84f5_0242ac140012row0_col1" class="data row0 col1" >6217</td>
#             </tr>
#             <tr>
#                         <th id="T_77c4caa2_6fad_11ec_84f5_0242ac140012level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %%
config_data_path = "cache/splitted-data"

save_config(config_data_path)

# %%
orchest.output(config_data_path, name="config_data_path")

# %%
import orchest

from pycaret.regression import compare_models, load_config

# %%
config_data_path = orchest.get_inputs()["config_data_path"]

# %%
load_config(config_data_path)

# %%
best_model = compare_models(fold=5)
# Out:
# <style  type="text/css" >
#     #T_821aed92_6fad_11ec_a37d_0242ac140012 th {
#           text-align: left;
#     }    #T_821aed92_6fad_11ec_a37d_0242ac140012row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_821aed92_6fad_11ec_a37d_0242ac140012row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_821aed92_6fad_11ec_a37d_0242ac140012row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_821aed92_6fad_11ec_a37d_0242ac140012row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_821aed92_6fad_11ec_a37d_0242ac140012row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_821aed92_6fad_11ec_a37d_0242ac140012row0_col5 {
# ...

# %%
best_model
# Out:
# GradientBoostingRegressor(random_state=6217)

# %%
orchest.output(best_model, name="model")
